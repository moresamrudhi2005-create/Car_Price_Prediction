# %%
import numpy as np
import pandas as pd
import pickle as pkl
import warnings
warnings.filterwarnings('ignore')

# %%
name=input("Enter name")
company=input("Enter Company")
year=int(input("Enter year"))
km_driven= int(input("Enter km_driven"))
fuel_type=input("Enter fuel_type")
# Out:
# Enter name Eon
# Enter Company Hyundai
# Enter year 2019
# Enter km_driven 20000
# Enter fuel_type Petrol

# %%
inputdata = pd.DataFrame(data=[[name,company,year,km_driven,fuel_type]],
                         columns=['name','company','year','kms_driven','fuel_type'])

# %%
inputdata
# Out:
#   name  company  year  kms_driven fuel_type
# 0  Eon  Hyundai  2019       20000    Petrol

# %%
model = pkl.load(open("CPP.pkl","rb+"))

# %%
model.predict(inputdata)
# Out:
# array([[402639.6623472]])
